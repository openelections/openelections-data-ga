# %%
import glob
import os

import pandas as pd

# %%
df = pd.concat(map(pd.read_csv, glob.glob(os.path.join('.', "20120731_*_precinct.csv"))), sort=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249085 entries, 0 to 607
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   absentee_by_mail     249085 non-null  int64
#  1   advance_in_person    208331 non-null  float64
#  2   advance_in_person_1  40754 non-null   float64
#  3   advance_in_person_2  58750 non-null   float64
#  4   candidate            249085 non-null  object
#  5   county               249085 non-null  object
#  6   district             129576 non-null  object
#  7   election_day         249085 non-null  int64
#  8   office               249085 non-null  object
#  9   party                99066 non-null   object
#  10  precinct             235953 non-null  object
#  11  provisional          249085 non-null  int64
#  12  votes                249085 non-null  int64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 26.6+ MB

# %%
df.head()
# Out:
#    absentee_by_mail  advance_in_person  advance_in_person_1  \
# 0                33              426.0                  NaN
# 1                 8               31.0                  NaN
# 2                 2               44.0                  NaN
# 3                 3              105.0                  NaN
# 4                 4               45.0                  NaN
#
#    advance_in_person_2        candidate      county district  election_day  \
# 0                  NaN  CHUCK EATON (I)  Jeff Davis        3           881
# 1                  NaN  CHUCK EATON (I)  Jeff Davis        3            94
# 2                  NaN  CHUCK EATON (I)  Jeff Davis        3            66
# 3                  NaN  CHUCK EATON (I)  Jeff Davis        3           181
# 4                  NaN  CHUCK EATON (I)  Jeff Davis        3            63
#
#                                   office party     precinct  provisional  \
# 0  Public Service Commission, District 3   REP          NaN            0
# ...

# %%
df.to_csv('ga_genearal_20120731.csv', index=False)
