# %%
import json
import os

from ipyfilechooser import FileChooser
import pandas as pd
import pydantic_core

import enhanced_json_model
import utils

# %%
source_path = '/Users/skunkworks/Development/openelections-sources-ga'
output_path = '/Users/skunkworks/Development/openelections-data-ga/2025/code'

# %%
# Documentation: https://github.com/crahan/ipyfilechooser
fc = FileChooser(source_path)
display(fc)
# Out:
# FileChooser(path='/Users/skunkworks/Development/openelections-sources-ga', filename='', title='', show_hidden=…

# %%
source_file = fc.selected

# %%
with open(source_file, 'r') as f:
    data = f.read()

# %%
m = enhanced_json_model.ElectionResults.model_validate(
    pydantic_core.from_json(data)
)

# %%
data = m.model_dump_json()

# %%
flatten_data = utils.flatten_precinct_level_election_data(data)

# %%
flatten_data[0:2]
# Out:
# [{'election_name': 'August 26, 2025 - Special Election - State Senate District 21',
#   'election_date': '2025-08-26',
#   'county': 'Cherokee County',
#   'number_precincts': 18,
#   'office': 'Special State Senate - District 21',
#   'candidate': 'Lance Calvert (Rep)',
#   'party': 'Rep',
#   'precinct_id': '003',
#   'precinct_name': 'Avery',
#   'precinct_reporting_status': 'Fully Reported',
#   'total_votes': 40,
#   'vote_type': 'Election Day',
#   'votes': None},
#  {'election_name': 'August 26, 2025 - Special Election - State Senate District 21',
#   'election_date': '2025-08-26',
#   'county': 'Cherokee County',
#   'number_precincts': 18,
#   'office': 'Special State Senate - District 21',
#   'candidate': 'Lance Calvert (Rep)',
#   'party': 'Rep',
#   'precinct_id': '003',
#   'precinct_name': 'Avery',
#   'precinct_reporting_status': 'Fully Reported',
#   'total_votes': 40,
#   'vote_type': 'Advance Voting',
#   'votes': None}]

# %%
if flatten_data:
    election_date = flatten_data[0].get('election_date').replace('-', '')
    filename = f'ga_{election_date}_precinct_level_data.json'
    output_filename = os.path.join(output_path, filename)
    with open(output_filename, 'w') as f:
        json.dump(flatten_data, f)
    print(output_filename)
else:
    print('No precinct data found...')
# Out:
# /Users/skunkworks/Development/openelections-data-ga/2025/code/ga_20250826_precinct_level_data.json

# %%
flatten_data = utils.flatten_county_level_election_data(data)

# %%
flatten_data[0:2]
# Out:
# [{'election_name': 'August 26, 2025 - Special Election - State Senate District 21',
#   'election_date': '2025-08-26',
#   'county': 'Cherokee County',
#   'office': 'Special State Senate - District 21',
#   'candidate': 'Lance Calvert (Rep)',
#   'party': 'Rep',
#   'vote_type': 'Election Day',
#   'votes': 671,
#   'total_votes': 1141},
#  {'election_name': 'August 26, 2025 - Special Election - State Senate District 21',
#   'election_date': '2025-08-26',
#   'county': 'Cherokee County',
#   'office': 'Special State Senate - District 21',
#   'candidate': 'Lance Calvert (Rep)',
#   'party': 'Rep',
#   'vote_type': 'Advance Voting',
#   'votes': 460,
#   'total_votes': 1141}]

# %%
if flatten_data:
    election_date = flatten_data[0].get('election_date').replace('-', '')
    filename = f'ga_{election_date}_county_level_data.json'
    output_filename = os.path.join(output_path, filename)
    with open(output_filename, 'w') as f:
        json.dump(flatten_data, f)
    print(output_filename)
else:
    print('No county data found...')
# Out:
# /Users/skunkworks/Development/openelections-data-ga/2025/code/ga_20250826_county_level_data.json
