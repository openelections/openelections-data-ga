# %%
import pandas as pd

# %%
df = pd.read_html('http://sos.ga.gov/elections/election_results/2008_0715/swgasenate.htm')

# %%
fullnames = df[1]

# %%
fullnames.shape
# Out:
# (579, 50)

# %%
fullnames.head(5)
# Out:
#                                                   0                      1   \
# 0  State Senator, District 1  100% of precincts r...                    NaN
# 1  Republican Candidates  Votes % of Votes Eric J...                    NaN
# 2                                                NaN  Republican Candidates
# 3                                                NaN           Eric Johnson
# 4                                                NaN                 Totals
#
#                       2           3           4   5   6             7   8   \
# 0                    NaN         NaN         NaN NaN NaN           NaN NaN
# 1  Republican Candidates       Votes  % of Votes NaN NaN  Eric Johnson NaN
# 2                  Votes  % of Votes         NaN NaN NaN           NaN NaN
# 3                    NaN        5400      100.0% NaN NaN           NaN NaN
# 4                   5400         NaN         NaN NaN NaN           NaN NaN
#
# ...

# %%
fullnames = fullnames[fullnames.columns[[0,1,3,4]]]

# %%
fullnames.head(5)
# Out:
#                                                    0                      1  \
# 0  State Senator, District 1  100% of precincts r...                    NaN
# 1  Republican Candidates  Votes % of Votes Eric J...                    NaN
# 2                                                NaN  Republican Candidates
# 3                                                NaN           Eric Johnson
# 4                                                NaN                 Totals
#
#             3           4
# 0         NaN         NaN
# 1       Votes  % of Votes
# 2  % of Votes         NaN
# 3        5400      100.0%
# 4         NaN         NaN

# %%
fullnames.columns = ['district', 'candidate', 'votes', 'percent']

# %%
fullnames.head()
# Out:
#                                             district              candidate  \
# 0  State Senator, District 1  100% of precincts r...                    NaN
# 1  Republican Candidates  Votes % of Votes Eric J...                    NaN
# 2                                                NaN  Republican Candidates
# 3                                                NaN           Eric Johnson
# 4                                                NaN                 Totals
#
#         votes     percent
# 0         NaN         NaN
# 1       Votes  % of Votes
# 2  % of Votes         NaN
# 3        5400      100.0%
# 4         NaN         NaN

# %%
fullnames.to_csv('2008_state_senate_fullname.csv', index=False)

# %%
df = pd.read_html('https://github.com/ATLJoeReed/openelections-data-ga/blob/c101d93abd19907a7c859999f31ef97c4f8a2745/2008/20080715__ga__general__primary__county.csv')

# %%
votes_20080715 = df[0]

# %%
votes_20080715.head()
# Out:
#    Unnamed: 0       office  candidate party    county  votes district
# 0         NaN  U.S. Senate  Chambliss     R   Appling    850      NaN
# 1         NaN  U.S. Senate     Totals     R   Appling    850      NaN
# 2         NaN  U.S. Senate  Chambliss     R  Atkinson     37      NaN
# 3         NaN  U.S. Senate     Totals     R  Atkinson     37      NaN
# 4         NaN  U.S. Senate  Chambliss     R     Bacon    957      NaN

# %%
votes_20080715.to_csv('votes_20080715.csv', index=False)
